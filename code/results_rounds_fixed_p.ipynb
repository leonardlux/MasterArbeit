# %% [markdown]
# # Goal: Plot logical error rate against # rounds for different distances
#
# probability should be chosen below threshold

# %%
import numpy as np

from tools.circuits import generate_steane_circuit 
from tools.error_models import add_noise, construct_circuit_noise_model
from tools.log_error_rate import count_logical_errors_ML, count_logical_errors_MWPM

# %%
import tools.graphics as graphic 
from importlib import reload
reload(graphic)
# Out:
# <module 'tools.graphics' from '/home/leo/Documents/MasterArbeit/code/new_start/tools/graphics.py'>

# %%
import matplotlib.pyplot as plt

# %%
def generate_data(
        distances,
        rounds,
        p,
        count_logical_errors_func,
        num_shots: int = 10_000,
        noise_model_func = construct_circuit_noise_model,
        noise_model_string = "circ",
        ):
    noise_model = noise_model_func(p) 

    log_error_rates = np.zeros((len(distances),len(rounds)))
    err_log_error_rates = np.zeros((len(distances),len(rounds)))
    for i_d, d in enumerate(distances):
        for i_r, r in enumerate(rounds):
            print(f"Currently calculating for d={d} and {r} rounds")
            n_circ = add_noise(
                circuit=generate_steane_circuit(distance=d, rounds=r), 
                noise_model=noise_model,
                )
            log_error_rates[i_d, i_r] = count_logical_errors_func(
                circuit=n_circ,
                distance=d,
                rounds=r,
                num_shots=num_shots,
                error_rate=p,
                noise_model=noise_model_string,
                observable="Z",
                probability=True,
            )
            err_log_error_rates[i_d, i_r] = (log_error_rates[i_d,i_r]*(1-log_error_rates[i_d,i_r])/num_shots)**(1/2) 
    return log_error_rates, err_log_error_rates

# %%
def plot(rounds,distances,log_error_rates,err_log_error_rates,title=""):
    plt.figure()
    plt.title(title)
    for i_d, d in enumerate(distances):
        plt.errorbar(
            rounds,
            log_error_rates[i_d],
            yerr=err_log_error_rates[i_d],
            label=f"$d={d}$",
        )
    plt.yscale("log")
    plt.legend()
    plt.xlabel("rounds")
    plt.ylabel("logical error rate")

# %%
# MWPM
# TODO determine threshold !
mwpm_distances = [3,5,7,9]
mwpm_rounds = np.arange(1,40)
mwpm_p = 5*10**-3
count_logical_errors_func = count_logical_errors_MWPM

mwpm_log_p, mwpm_log_p_err = generate_data(
   distances=mwpm_distances,
   rounds=mwpm_rounds,
   p=mwpm_p, 
   count_logical_errors_func=count_logical_errors_func,
)

# %%
plot(
    rounds=mwpm_rounds,
    distances=mwpm_distances,
    log_error_rates=mwpm_log_p,
    err_log_error_rates=mwpm_log_p_err,
    title=f"MWPM plot (p={mwpm_p:.4f})"
    )

# %%
# MWPM
# TODO determine threshold !
ml_distances = [3,5]
ml_rounds = np.arange(1,5)
ml_p = 5*10**-3
count_logical_errors_func = count_logical_errors_ML

ml_log_p, ml_log_p_err = generate_data(
   distances=mwpm_distances,
   rounds=mwpm_rounds,
   p=mwpm_p, 
   count_logical_errors_func=count_logical_errors_func,
   num_shots=5_000,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 8
#       5 ml_p = 5*10**-3
#       6 count_logical_errors_func = count_logical_errors_ML
# ----> 8 ml_log_p, ml_log_p_err = generate_data(
#       9    distances=mwpm_distances,
#      10    rounds=mwpm_rounds,
#      11    p=mwpm_p,
#      12    count_logical_errors_func=count_logical_errors_func,
#      13    num_shots=5_000,
#      14 )
#
# Cell In[5], line 20, in generate_data(distances, rounds, p, count_logical_errors_func, num_shots, noise_model_func, noise_model_string)
#      15     for i_r, r in enumerate(rounds):
#      16         n_circ = add_noise(
#      17             circuit=generate_steane_circuit(distance=d, rounds=r),
#      18             noise_model=noise_model,
#      19             )
# ---> 20         log_error_rates[i_d, i_r] = count_logical_errors_func(
#      21             circuit=n_circ,
#      22             distance=d,
#      23             rounds=r,
#      24             num_shots=num_shots,
#      25             error_rate=p,
#      26             noise_model=noise_model_string,
#      27             observable="Z",
#      28             probability=True,
#      29         )
#      30         err_log_error_rates[i_d, i_r] = (log_error_rates[i_d,i_r]*(1-log_error_rates[i_d,i_r])/num_shots)**(1/2)
#      31 return log_error_rates, err_log_error_rates
#
# File ~/Documents/MasterArbeit/code/new_start/tools/log_error_rate.py:156, in count_logical_errors_ML(circuit, num_shots, distance, error_rate, rounds, probability, observable, noise_model, **kwargs)
#     154 for i_shot in numba.prange(num_shots):
#     155     for i_round in numba.prange(rounds):
# --> 156         predicitons[i_shot, i_round], pauli_repr_flips[i_shot,i_round] = decode_half_syndrome_func(
#     157             d,
#     158             p,
#     159             rel_synd[i_shot,i_round],
#     160         )
#     161 multi_round_pred = np.sum(predicitons,axis=1)%2
#     162 multi_round_pauli_flip = np.sum(pauli_repr_flips, axis=1)%2
#
# File ~/Documents/MasterArbeit/code/new_start/tools/ml_decoder.py:234, in decode_half_syndrome_aron(d, p, h_syndrome, only_obs_flip)
#     232 f_I, c_f = stabilizer_to_pauli(d, z_matrix)
#     233 f_L, _ = stabilizer_to_pauli(d, z_matrix, add_logical=True)
# --> 234 p_I = simulation_mld(
#     235     p,
#     236     d,
#     237     error_converter(int(d), f_I),
#     238     )
#     239 p_L = simulation_mld(
#     240     p,
#     241     d,
#     242     error_converter(int(d), f_L),
#     243     )
#     244 obs_flip = True if p_I < p_L else False
#
# KeyboardInterrupt:

# %%
plot(
    rounds=ml_rounds,
    distances=ml_distances,
    log_error_rates=ml_log_p,
    err_log_error_rates=ml_log_p_err,
    title=f"MWPM plot (p={ml_p:.4f})"
    )
