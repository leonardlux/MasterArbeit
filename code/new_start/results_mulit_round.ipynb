# %%
import numpy as np

from tools.surface_code import generate_steane_circuit, generate_surface_code_circuit
from tools.error_models import add_noise, construct_basic_noise_model, construct_circuit_noise_model, construct_bit_flip_model 
from tools.log_error_rate import generate_log_error_rates,count_logical_errors_using_MWPM, count_logical_errors_using_ML,  gen_error_model_count_logical_error_MWPM, gen_multi_rep_count_logical_error_MWPM, count_logical_errors_using_ML_FT, count_logical_errors_using_ML_rounds
from tools.syndrome import split_and_xor_syndrome, split_syndromes_rounds

# %%
import tools.graphics as graphic 
from importlib import reload
reload(graphic)
# Out:
# <module 'tools.graphics' from '/home/leo/Documents/MasterArbeit/code/new_start/tools/graphics.py'>

# %%
distances = [3,5]
noise_set = np.logspace(-3.5,-0.9, num=10)
num_shots = 20_000 
count_logical_func = count_logical_errors_using_ML_rounds

# %%
rounds = 1

steane_circuits = [generate_steane_circuit(d, rounds=rounds) for d in distances]


log_error_rates_r1, y_errs_r1 = generate_log_error_rates(
    steane_circuits,
    construct_circuit_noise_model,
    count_log_error_fct=count_logical_func,
    distances= distances ,
    rounds=rounds,
    noise_set= noise_set,
    num_shots= num_shots,
)

# %%
rounds = 2

steane_circuits = [generate_steane_circuit(d, rounds=rounds) for d in distances]


log_error_rates_r2, y_errs_r2 = generate_log_error_rates(
    steane_circuits,
    construct_circuit_noise_model,
    count_log_error_fct=count_logical_func,
    distances= distances ,
    rounds=rounds,
    noise_set= noise_set,
    num_shots= num_shots,
)

# %%
rounds = 3

steane_circuits = [generate_steane_circuit(d, rounds=rounds) for d in distances]


log_error_rates_r3, y_errs_r3 = generate_log_error_rates(
    steane_circuits,
    construct_circuit_noise_model,
    count_log_error_fct=count_logical_func,
    distances= distances ,
    rounds=rounds,
    noise_set= noise_set,
    num_shots= num_shots,
)

# %%
rounds = 4

steane_circuits = [generate_steane_circuit(d, rounds=rounds) for d in distances]


log_error_rates_r4, y_errs_r4 = generate_log_error_rates(
    steane_circuits,
    construct_circuit_noise_model,
    count_log_error_fct=count_logical_func,
    distances= distances ,
    rounds=rounds,
    noise_set= noise_set,
    num_shots= num_shots,
)

# %%
graphic.overlay_different_slopes(
    [log_error_rates_r1,log_error_rates_r2,log_error_rates_r3,log_error_rates_r4],
    [y_errs_r1,y_errs_r2,y_errs_r3,y_errs_r4],
    distances=distances,
    noise_set=noise_set,
    titles=["1 Round", "2 Rounds", "3 Rounds", "4 Rounds"],
    reference_lines= True,
)

# %%
graphic.plot_diff_noise_level(
    log_error_rates=log_error_rates_r1,
    y_errs=y_errs_r1,
    distances=distances,
    noise_set=noise_set,
    reference_lines=True,
    title="1 Round",
)
graphic.plot_diff_noise_level(
    log_error_rates=log_error_rates_r2,
    y_errs=y_errs_r2,
    distances=distances,
    noise_set=noise_set,
    reference_lines=True,
    title="2 Rounds",
)
graphic.plot_diff_noise_level(
    log_error_rates=log_error_rates_r3,
    y_errs=y_errs_r3,
    distances=distances,
    noise_set=noise_set,
    reference_lines=True,
    title="3 Rounds",
)
graphic.plot_diff_noise_level(
    log_error_rates=log_error_rates_r4,
    y_errs=y_errs_r4,
    distances=distances,
    noise_set=noise_set,
    reference_lines=True,
    title="3 Rounds",
)
